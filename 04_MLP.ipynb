# %%
import pandas as pd
import numpy as np
import random
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# ### **Preparo dos Datasets**

# %%
df_treino = pd.read_csv('Treino.csv')
X = df_treino.iloc[:, 0:9].values
y = df_treino.iloc[:, 9].values

df_teste = pd.read_csv('Teste.csv')
X_teste = df_teste.iloc[:, 0:9].values
y_teste = df_teste.iloc[:, 9].values


df_validacao = pd.read_csv('Validacao.csv')
X_validacao = df_validacao.iloc[:, 0:9].values
y_validacao = df_validacao.iloc[:, 9].values

# %%
df_treino.describe()
# Out:
#                 J1           J2           J3           J4           J5  \
# count  1190.000000  1190.000000  1190.000000  1190.000000  1190.000000
# mean      0.013445     0.024370     0.031092     0.007563     0.006723
# std       0.818101     0.813207     0.831391     0.809392     0.848462
# min      -1.000000    -1.000000    -1.000000    -1.000000    -1.000000
# 25%      -1.000000    -1.000000    -1.000000    -1.000000    -1.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       1.000000     1.000000     1.000000     1.000000     1.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 J6           J7           J8           J9    Resultado
# count  1190.000000  1190.000000  1190.000000  1190.000000  1190.000000
# mean      0.035294     0.028571     0.031933     0.062185     0.537815
# std       0.814357     0.829963     0.819642     0.820981     1.151223
# min      -1.000000    -1.000000    -1.000000    -1.000000    -1.000000
# 25%      -1.000000    -1.000000    -1.000000    -1.000000    -1.000000
# 50%       0.000000     0.000000     0.000000     0.000000     1.000000
# 75%       1.000000     1.000000     1.000000     1.000000     2.000000
# max       1.000000     1.000000     1.000000     1.000000     2.000000

# %%
df_treino['Resultado'].value_counts()
# Out:
# Resultado
#  1    320
# -1    320
#  2    320
#  0    230
# Name: count, dtype: int64

# %%
df_validacao.describe()
# Out:
#                J1          J2          J3          J4          J5          J6  \
# count  149.000000  149.000000  149.000000  149.000000  149.000000  149.000000
# mean    -0.026846   -0.060403    0.167785    0.040268    0.134228    0.067114
# std      0.829737    0.807299    0.808759    0.829190    0.810886    0.794104
# min     -1.000000   -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 25%     -1.000000   -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                J7          J8          J9   Resultado
# count  149.000000  149.000000  149.000000  149.000000
# mean    -0.046980   -0.060403   -0.020134    0.536913
# std      0.824749    0.815626    0.842052    1.153862
# min     -1.000000   -1.000000   -1.000000   -1.000000
# 25%     -1.000000   -1.000000   -1.000000   -1.000000
# 50%      0.000000    0.000000    0.000000    1.000000
# 75%      1.000000    1.000000    1.000000    2.000000
# max      1.000000    1.000000    1.000000    2.000000

# %%
df_validacao['Resultado'].value_counts()
# Out:
# Resultado
#  1    40
# -1    40
#  2    40
#  0    29
# Name: count, dtype: int64

# %%
df_teste.describe()
# Out:
#                J1          J2          J3          J4          J5          J6  \
# count  149.000000  149.000000  149.000000  149.000000  149.000000  149.000000
# mean     0.046980    0.087248   -0.093960    0.067114    0.107383    0.154362
# std      0.856892    0.779231    0.791358    0.843612    0.863219    0.811445
# min     -1.000000   -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 25%     -1.000000   -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                J7          J8          J9   Resultado
# count  149.000000  149.000000  149.000000  149.000000
# mean     0.046980   -0.080537   -0.053691    0.536913
# std      0.856892    0.818013    0.875995    1.153862
# min     -1.000000   -1.000000   -1.000000   -1.000000
# 25%     -1.000000   -1.000000   -1.000000   -1.000000
# 50%      0.000000    0.000000    0.000000    1.000000
# 75%      1.000000    1.000000    1.000000    2.000000
# max      1.000000    1.000000    1.000000    2.000000

# %%
df_teste['Resultado'].value_counts()
# Out:
# Resultado
#  1    40
# -1    40
#  2    40
#  0    29
# Name: count, dtype: int64

# %% [markdown]
# ### **Treino do Modelo**

# %%
# Utilizando os parâmetros padrão da classe MLPClassifier
mlp = MLPClassifier(verbose=True);
mlp.fit(X, y)
# Out:
# Iteration 1, loss = 1.38916719
# Iteration 2, loss = 1.34112994
# Iteration 3, loss = 1.29950045
# Iteration 4, loss = 1.26347691
# Iteration 5, loss = 1.22896083
# Iteration 6, loss = 1.19675132
# Iteration 7, loss = 1.16617821
# Iteration 8, loss = 1.13598227
# Iteration 9, loss = 1.10624091
# Iteration 10, loss = 1.07712771
# Iteration 11, loss = 1.04788966
# Iteration 12, loss = 1.01955325
# Iteration 13, loss = 0.99071979
# Iteration 14, loss = 0.96260846
# Iteration 15, loss = 0.93425297
# Iteration 16, loss = 0.90683165
# Iteration 17, loss = 0.87913866
# Iteration 18, loss = 0.85210471
# Iteration 19, loss = 0.82526668
# Iteration 20, loss = 0.79905879
# Iteration 21, loss = 0.77296888
# Iteration 22, loss = 0.74758450
# Iteration 23, loss = 0.72276975
# Iteration 24, loss = 0.69874802
# Iteration 25, loss = 0.67542905
# Iteration 26, loss = 0.65292157
# Iteration 27, loss = 0.63095265
# Iteration 28, loss = 0.60985936
# Iteration 29, loss = 0.58954984
# Iteration 30, loss = 0.57001206
# Iteration 31, loss = 0.55120979
# Iteration 32, loss = 0.53317921
# Iteration 33, loss = 0.51613177
# Iteration 34, loss = 0.49969167
# Iteration 35, loss = 0.48396322
# Iteration 36, loss = 0.46917000
# Iteration 37, loss = 0.45500494
# Iteration 38, loss = 0.44132615
# Iteration 39, loss = 0.42854936
# Iteration 40, loss = 0.41635157
# Iteration 41, loss = 0.40457697
# Iteration 42, loss = 0.39334676
# Iteration 43, loss = 0.38269007
# Iteration 44, loss = 0.37254588
# Iteration 45, loss = 0.36290651
# Iteration 46, loss = 0.35388613
# Iteration 47, loss = 0.34479420
# Iteration 48, loss = 0.33634171
# Iteration 49, loss = 0.32838773
# Iteration 50, loss = 0.32051973
# Iteration 51, loss = 0.31331996
# Iteration 52, loss = 0.30607402
# Iteration 53, loss = 0.29933505
# Iteration 54, loss = 0.29276765
# Iteration 55, loss = 0.28642814
# Iteration 56, loss = 0.28030474
# Iteration 57, loss = 0.27448561
# Iteration 58, loss = 0.26881989
# Iteration 59, loss = 0.26352108
# Iteration 60, loss = 0.25808493
# Iteration 61, loss = 0.25320008
# Iteration 62, loss = 0.24823296
# Iteration 63, loss = 0.24352378
# Iteration 64, loss = 0.23910379
# Iteration 65, loss = 0.23449030
# Iteration 66, loss = 0.23020459
# Iteration 67, loss = 0.22606575
# Iteration 68, loss = 0.22213271
# Iteration 69, loss = 0.21807248
# Iteration 70, loss = 0.21464767
# Iteration 71, loss = 0.21062766
# Iteration 72, loss = 0.20733295
# Iteration 73, loss = 0.20358183
# Iteration 74, loss = 0.20002594
# Iteration 75, loss = 0.19683225
# Iteration 76, loss = 0.19352093
# Iteration 77, loss = 0.19042494
# Iteration 78, loss = 0.18745900
# Iteration 79, loss = 0.18432758
# Iteration 80, loss = 0.18130132
# Iteration 81, loss = 0.17858419
# Iteration 82, loss = 0.17581123
# Iteration 83, loss = 0.17289507
# Iteration 84, loss = 0.17036549
# Iteration 85, loss = 0.16768367
# Iteration 86, loss = 0.16518863
# Iteration 87, loss = 0.16270212
# Iteration 88, loss = 0.16018305
# Iteration 89, loss = 0.15792650
# Iteration 90, loss = 0.15547756
# Iteration 91, loss = 0.15324020
# Iteration 92, loss = 0.15104800
# Iteration 93, loss = 0.14882869
# Iteration 94, loss = 0.14667758
# Iteration 95, loss = 0.14456400
# Iteration 96, loss = 0.14246183
# Iteration 97, loss = 0.14056463
# Iteration 98, loss = 0.13850788
# Iteration 99, loss = 0.13670163
# Iteration 100, loss = 0.13481572
# Iteration 101, loss = 0.13289465
# Iteration 102, loss = 0.13125359
# Iteration 103, loss = 0.12939725
# Iteration 104, loss = 0.12778566
# Iteration 105, loss = 0.12604175
# Iteration 106, loss = 0.12440881
# Iteration 107, loss = 0.12281985
# Iteration 108, loss = 0.12131526
# Iteration 109, loss = 0.11977934
# Iteration 110, loss = 0.11823617
# Iteration 111, loss = 0.11674602
# Iteration 112, loss = 0.11527169
# Iteration 113, loss = 0.11387874
# Iteration 114, loss = 0.11245095
# Iteration 115, loss = 0.11120543
# Iteration 116, loss = 0.10972921
# Iteration 117, loss = 0.10837118
# Iteration 118, loss = 0.10718673
# Iteration 119, loss = 0.10594532
# Iteration 120, loss = 0.10452510
# Iteration 121, loss = 0.10351861
# Iteration 122, loss = 0.10215907
# Iteration 123, loss = 0.10107542
# Iteration 124, loss = 0.09989980
# Iteration 125, loss = 0.09878604
# Iteration 126, loss = 0.09771618
# Iteration 127, loss = 0.09659528
# Iteration 128, loss = 0.09556167
# Iteration 129, loss = 0.09467541
# Iteration 130, loss = 0.09364583
# Iteration 131, loss = 0.09248785
# Iteration 132, loss = 0.09153614
# Iteration 133, loss = 0.09050972
# Iteration 134, loss = 0.08960334
# Iteration 135, loss = 0.08867680
# Iteration 136, loss = 0.08766428
# Iteration 137, loss = 0.08679552
# Iteration 138, loss = 0.08592589
# Iteration 139, loss = 0.08498445
# Iteration 140, loss = 0.08434536
# Iteration 141, loss = 0.08335018
# Iteration 142, loss = 0.08257327
# Iteration 143, loss = 0.08162810
# Iteration 144, loss = 0.08079652
# Iteration 145, loss = 0.08025855
# Iteration 146, loss = 0.07935874
# Iteration 147, loss = 0.07879853
# Iteration 148, loss = 0.07774103
# Iteration 149, loss = 0.07717598
# Iteration 150, loss = 0.07633056
# Iteration 151, loss = 0.07560861
# Iteration 152, loss = 0.07497332
# Iteration 153, loss = 0.07415308
# Iteration 154, loss = 0.07353768
# Iteration 155, loss = 0.07280474
# Iteration 156, loss = 0.07217738
# Iteration 157, loss = 0.07149751
# Iteration 158, loss = 0.07072595
# Iteration 159, loss = 0.07018303
# Iteration 160, loss = 0.06946391
# Iteration 161, loss = 0.06890341
# Iteration 162, loss = 0.06836144
# Iteration 163, loss = 0.06767154
# Iteration 164, loss = 0.06702823
# Iteration 165, loss = 0.06656746
# Iteration 166, loss = 0.06589736
# Iteration 167, loss = 0.06529949
# Iteration 168, loss = 0.06474932
# Iteration 169, loss = 0.06419610
# Iteration 170, loss = 0.06375054
# Iteration 171, loss = 0.06313924
# Iteration 172, loss = 0.06259881
# Iteration 173, loss = 0.06213583
# Iteration 174, loss = 0.06166585
# Iteration 175, loss = 0.06102710
# Iteration 176, loss = 0.06055745
# Iteration 177, loss = 0.06005017
# Iteration 178, loss = 0.05953925
# Iteration 179, loss = 0.05918872
# Iteration 180, loss = 0.05860100
# Iteration 181, loss = 0.05806485
# Iteration 182, loss = 0.05767924
# Iteration 183, loss = 0.05714196
# Iteration 184, loss = 0.05671365
# Iteration 185, loss = 0.05625835
# Iteration 186, loss = 0.05581711
# Iteration 187, loss = 0.05544476
# Iteration 188, loss = 0.05495246
# Iteration 189, loss = 0.05448959
# Iteration 190, loss = 0.05410279
# Iteration 191, loss = 0.05384136
# Iteration 192, loss = 0.05326621
# Iteration 193, loss = 0.05281363
# Iteration 194, loss = 0.05237361
# Iteration 195, loss = 0.05216594
# Iteration 196, loss = 0.05157657
# Iteration 197, loss = 0.05120010
# Iteration 198, loss = 0.05077922
# Iteration 199, loss = 0.05040653
# Iteration 200, loss = 0.05001842
# /home/death/anaconda3/envs/IA/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(verbose=True)

# %%
# Refinando os parâmetros do MLP
mlp = MLPClassifier(solver='adam', hidden_layer_sizes=(80,), learning_rate_init=0.01, max_iter=100, momentum=0.9, verbose=True, random_state=42);
mlp.fit(X, y)
# Out:
# Iteration 1, loss = 1.26741811
# Iteration 2, loss = 0.99045609
# Iteration 3, loss = 0.77978941
# Iteration 4, loss = 0.59439127
# Iteration 5, loss = 0.44958963
# Iteration 6, loss = 0.34823110
# Iteration 7, loss = 0.28044409
# Iteration 8, loss = 0.23425833
# Iteration 9, loss = 0.20126389
# Iteration 10, loss = 0.17527732
# Iteration 11, loss = 0.15384751
# Iteration 12, loss = 0.13800070
# Iteration 13, loss = 0.12320292
# Iteration 14, loss = 0.11051212
# Iteration 15, loss = 0.10142871
# Iteration 16, loss = 0.09173599
# Iteration 17, loss = 0.08389666
# Iteration 18, loss = 0.07660696
# Iteration 19, loss = 0.06907326
# Iteration 20, loss = 0.06591863
# Iteration 21, loss = 0.05971271
# Iteration 22, loss = 0.05527698
# Iteration 23, loss = 0.05248103
# Iteration 24, loss = 0.04970371
# Iteration 25, loss = 0.04630973
# Iteration 26, loss = 0.04470579
# Iteration 27, loss = 0.04179021
# Iteration 28, loss = 0.03934127
# Iteration 29, loss = 0.03928929
# Iteration 30, loss = 0.03498915
# Iteration 31, loss = 0.03344944
# Iteration 32, loss = 0.03124073
# Iteration 33, loss = 0.02962287
# Iteration 34, loss = 0.02761961
# Iteration 35, loss = 0.02680851
# Iteration 36, loss = 0.02570025
# Iteration 37, loss = 0.02449240
# Iteration 38, loss = 0.02304422
# Iteration 39, loss = 0.02248892
# Iteration 40, loss = 0.02141180
# Iteration 41, loss = 0.02010625
# Iteration 42, loss = 0.01981606
# Iteration 43, loss = 0.01897141
# Iteration 44, loss = 0.01865722
# Iteration 45, loss = 0.01785948
# Iteration 46, loss = 0.01686401
# Iteration 47, loss = 0.01587944
# Iteration 48, loss = 0.01537845
# Iteration 49, loss = 0.01487403
# Iteration 50, loss = 0.01432995
# Iteration 51, loss = 0.01390370
# Iteration 52, loss = 0.01321352
# Iteration 53, loss = 0.01270634
# Iteration 54, loss = 0.01274718
# Iteration 55, loss = 0.01190352
# Iteration 56, loss = 0.01177006
# Iteration 57, loss = 0.01141966
# Iteration 58, loss = 0.01078646
# Iteration 59, loss = 0.01098802
# Iteration 60, loss = 0.01017745
# Iteration 61, loss = 0.00996587
# Iteration 62, loss = 0.00975973
# Iteration 63, loss = 0.00958212
# Iteration 64, loss = 0.00889894
# Iteration 65, loss = 0.00919911
# Iteration 66, loss = 0.00861407
# Iteration 67, loss = 0.00821828
# Iteration 68, loss = 0.00799334
# Iteration 69, loss = 0.00825324
# Iteration 70, loss = 0.00759813
# Iteration 71, loss = 0.00755536
# Iteration 72, loss = 0.00733547
# Iteration 73, loss = 0.00708378
# Iteration 74, loss = 0.00680098
# Iteration 75, loss = 0.00664329
# Iteration 76, loss = 0.00637616
# Iteration 77, loss = 0.00632412
# Iteration 78, loss = 0.00608438
# Iteration 79, loss = 0.00590840
# Iteration 80, loss = 0.00601018
# Iteration 81, loss = 0.00555936
# Iteration 82, loss = 0.00554788
# Iteration 83, loss = 0.00544286
# Iteration 84, loss = 0.00533597
# Iteration 85, loss = 0.00510954
# Iteration 86, loss = 0.00512714
# Iteration 87, loss = 0.00495634
# Iteration 88, loss = 0.00483946
# Iteration 89, loss = 0.00477789
# Iteration 90, loss = 0.00475517
# Iteration 91, loss = 0.00441411
# Iteration 92, loss = 0.00457991
# Iteration 93, loss = 0.00433495
# Iteration 94, loss = 0.00421737
# Iteration 95, loss = 0.00418202
# Iteration 96, loss = 0.00409124
# Iteration 97, loss = 0.00395926
# Iteration 98, loss = 0.00384068
# Iteration 99, loss = 0.00385740
# Iteration 100, loss = 0.00372612
# /home/death/anaconda3/envs/IA/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(hidden_layer_sizes=(80,), learning_rate_init=0.01, max_iter=100,
#               random_state=42, verbose=True)

# %% [markdown]
# ### **Testes**

# %%
# Utilizando o dataset de teste para avaliar o modelo
y_predicao = mlp.predict(X_teste)


acerto = 0
for i in range(0, len(y_predicao)):
  if y_predicao[i] == y_teste[i]: acerto = acerto + 1

print("Acuracia: ", acerto/len(y_predicao))
print(classification_report(y_teste, y_predicao))

confusion_matrix(y_teste, y_predicao)
# Out:
# Acuracia:  0.9932885906040269
#               precision    recall  f1-score   support
#
#           -1       1.00      1.00      1.00        40
#            0       1.00      1.00      1.00        29
#            1       0.98      1.00      0.99        40
#            2       1.00      0.97      0.99        40
#
#     accuracy                           0.99       149
#    macro avg       0.99      0.99      0.99       149
# weighted avg       0.99      0.99      0.99       149
# array([[40,  0,  0,  0],
#        [ 0, 29,  0,  0],
#        [ 0,  0, 40,  0],
#        [ 0,  0,  1, 39]])

# %%
# Utilizando o dataset de validação para avaliar o modelo

y_predicao = mlp.predict(X_validacao)


acerto = 0
for i in range(0, len(y_predicao)):
  if y_predicao[i] == y_validacao[i]: acerto = acerto + 1

print("Acuracia: ", acerto/len(y_predicao))
print(classification_report(y_validacao, y_predicao))

confusion_matrix(y_validacao, y_predicao)
# Out:
# Acuracia:  0.9865771812080537
#               precision    recall  f1-score   support
#
#           -1       1.00      1.00      1.00        40
#            0       1.00      1.00      1.00        29
#            1       0.95      1.00      0.98        40
#            2       1.00      0.95      0.97        40
#
#     accuracy                           0.99       149
#    macro avg       0.99      0.99      0.99       149
# weighted avg       0.99      0.99      0.99       149
# array([[40,  0,  0,  0],
#        [ 0, 29,  0,  0],
#        [ 0,  0, 40,  0],
#        [ 0,  0,  2, 38]])

# %%
# Para cada linha no dataset, executar clf.predict e imprimir o resultado quando for diferente do esperado.
df_empate = pd.read_csv('Validacao.csv')

for index, row in df_empate.iterrows():
    features = row.drop('Resultado').values.reshape(1, -1)
    prediction = mlp.predict(features)
    actual_result = row['Resultado']
    if prediction != actual_result:
        print(f"Index: {index}, Prediction: {prediction[0]}, Actual Result: {actual_result}")
# Out:
# Index: 118, Prediction: 1, Actual Result: 2
# Index: 148, Prediction: 1, Actual Result: 2

# %% [markdown]
# ### **Partida**

# %% [markdown]
# ### **Função para plotagem do tabuleiro**

# %%
# Plotagem do tabuleiro

import matplotlib.pyplot as plt

def plot_board(board,predicao=None):
    if predicao == 1:
        predicao = 'X ganhou'
    elif predicao == -1:
        predicao = 'O ganhou'
    elif predicao == 0:
        predicao = 'Empate'
    else:
        predicao = 'Ainda tem jogo'

    board = np.array(board).reshape(3, 3)

    
    fig, ax = plt.subplots()
    ax.set_xlim(0, 3)
    ax.set_ylim(0, 3)
    ax.text(-0.25, 2.5, '1', fontsize=42, ha='center', va='center', color='black')
    ax.text(-0.25, 1.5, '2', fontsize=42, ha='center', va='center', color='black')
    ax.text(-0.25, 0.5, '3', fontsize=42, ha='center', va='center', color='black')

    ax.text(0.5, 3.25, '1', fontsize=42, ha='center', va='center', color='black')
    ax.text(1.5, 3.25, '2', fontsize=42, ha='center', va='center', color='black')
    ax.text(2.5, 3.25, '3', fontsize=42, ha='center', va='center', color='black')

    plt.plot([1, 1], [0, 3], color='black', linewidth=2)
    plt.plot([2, 2], [0, 3], color='black', linewidth=2)
    plt.plot([0, 3], [1, 1], color='black', linewidth=2)
    plt.plot([0, 3], [2, 2], color='black', linewidth=2)

    for i in range(3):
        for j in range(3):
            mark = board[i][j]
            if mark == 1:
                plt.text(j + 0.5, 2.5 - i, 'X', fontsize=42, ha='center', va='center', color='black')
            elif mark == -1:
                plt.text(j + 0.5, 2.5 - i, 'O', fontsize=42, ha='center', va='center', color='black')

    if predicao is not None:
        plt.text(1.5, -0.5, 'Status: ' + predicao, fontsize=42, ha='center', va='center', color='black')

    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_aspect('equal')

    plt.show()

# %% [markdown]
# ##### **Funções para realização de jogadas**

# %%
# Função para coleta da jogada
def coleta_jogada():
    # Coletando os valores por meio de um input
    linha, coluna = input("Informe a linha e a coluna onde deseja incluir o x. Ex: [1,2]").split(",")
    
    # Convertendo os valores para inteiro
    return int(linha), int(coluna)

# Função para validação da posição informada para realização da jogada
def valida_jogada(jogada,linha,coluna):
    
    # Conversão da jogada em um array 3x3
    jogada = np.array(jogada).reshape(3,3)

    print("Linha:",linha)
    print("Linha:",coluna)
        
    # Verificar se o valor na posição especificada é igual a zero
    if jogada[linha-1][coluna-1] == 0:
        return True
    
    return False
    

# Função para realização da jogada do computador a partir de uma função aleatória
def jogada_COM(jogada):
    jogada_feita = False
    
    while not jogada_feita: 
        # Escolha de um índices de linha e coluna na lista
        linha = random.randint(0,2)
        coluna = random.randint(0,2)

        # Caso a posição escolhida esteja livre realiza a modificação
        if jogada[linha][coluna] not in [1,-1]:
            # Atrubuição realizada na posição aleatória escolhida
            jogada[linha,coluna] = -1
            jogada_feita = True
        
    return jogada


def ajuste_jogada(jogada,linha,coluna):
    # Conversão da jogada em um array 3x3
    jogada = np.array(jogada).reshape(3,3)

    # Substituindo o valor da posição informada em 1
    jogada[linha-1,coluna-1] = 1

    return jogada

# %% [markdown]
# #### **Realização da partida**

# %%
from IPython.display import clear_output

# Convertendo a lista de jogadas em um array 3x3
jogada = [0,0,0,0,0,0,0,0,0]
plot_board(jogada)

finalizar_jogo = False

while not finalizar_jogo:
    clear_output(wait=True)
    # Coletando a jogada
    linha,coluna = coleta_jogada()
    
    # Chamando a função de validação de jogada
    if valida_jogada(jogada,linha,coluna):
        # Realizando o ajuste da jogada a partir das posições de inserção informadas
        jogada = ajuste_jogada(jogada,linha,coluna)
        print('Jogada realizada!')
    else:
        print("Jogada não realizada")
        continue # Recomeça solicitando a jogada para o usuário
    
    # Redefinindo o shape do array 2d para usar no classificador
    jogada = jogada.reshape(9,).reshape(1,-1)

    # Obtenção do status do jogo após jogada do usuário
    predicao = mlp.predict(jogada)
    
    # Caso haja um vencedor o loop será encerrado
    if str(predicao) != "[2]":
        finalizar_jogo = True
        plot_board(jogada,predicao)
        break
    
    jogada = jogada.reshape(3,3)

    # Realização de jogada da máquina
    jogada = jogada_COM(jogada)

    # Redefinindo o shape do array para usar no classificador
    jogada = jogada.reshape(9,).reshape(1,-1)

    # Obtenção do status do jogo após jogada da máquina
    predicao = mlp.predict(jogada)

    # Plotando o tabuleiro 
    plot_board(jogada,predicao)
    
    # Caso haja um vencedor o loop será encerrado
    if str(predicao) != "[2]":
        finalizar_jogo = True
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[427], line 12
#      10 clear_output(wait=True)
#      11 # Coletando a jogada
# ---> 12 linha,coluna = coleta_jogada()
#      14 # Chamando a função de validação de jogada
#      15 if valida_jogada(jogada,linha,coluna):
#      16     # Realizando o ajuste da jogada a partir das posições de inserção informadas
#
# Cell In[426], line 4, in coleta_jogada()
#       2 def coleta_jogada():
#       3     # Coletando os valores por meio de um input
# ----> 4     linha, coluna = input("Informe a linha e a coluna onde deseja incluir o x. Ex: [1,2]").split(",")
#       6     # Convertendo os valores para inteiro
#       7     return int(linha), int(coluna)
#
# ValueError: too many values to unpack (expected 2)
